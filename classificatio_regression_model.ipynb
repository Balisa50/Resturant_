# %%
import pandas as pd

# %%
data = "C:/Users/Abdoulie Balisa/OneDrive/Desktop/clean_churn_data.csv"
churn = pd.read_csv(data)
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
churn['churn_encoded'] = le.fit_transform(churn['Churn'])
churn
# Out:
#     CustomerID  Gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0            1    Male              0     Yes         No       1          Yes
# 1            2  Female              1      No        Yes       2           No
# 2            3    Male              0     Yes         No       3          Yes
# 3            4  Female              1      No        Yes       4           No
# 4            5    Male              0     Yes         No       5          Yes
# ..         ...     ...            ...     ...        ...     ...          ...
# 95          96  Female              1      No        Yes       0           No
# 96          97    Male              0     Yes         No       1          Yes
# 97          98  Female              1      No        Yes       2           No
# 98          99    Male              0     Yes         No       3          Yes
# 99         100  Female              1      No        Yes       4           No
#
# ...
